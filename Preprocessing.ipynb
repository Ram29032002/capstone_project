# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
dataset=pd.read_csv("Device_Monitering.csv")

# %%
dataset.isnull()
# Out:
#          date  serial_number  model  capacity_bytes  failure  datacenter  \
# 0       False          False  False           False    False       False
# 1       False          False  False           False    False       False
# 2       False          False  False           False    False       False
# 3       False          False  False           False    False       False
# 4       False          False  False           False    False       False
# ...       ...            ...    ...             ...      ...         ...
# 331728  False          False  False           False    False       False
# 331729  False          False  False           False    False       False
# 331730  False          False  False           False    False       False
# 331731  False          False  False           False    False       False
# 331732  False          False  False           False    False       False
#
#         cluster_id  vault_id  pod_id  pod_slot_num  ...  smart_250_normalized  \
# ...

# %%
dataset.isnull().sum()
# Out:
# date                         0
# serial_number                0
# model                        0
# capacity_bytes               0
# failure                      0
#                          ...
# smart_252_raw           331732
# smart_254_normalized    331534
# smart_254_raw           331534
# smart_255_normalized    331733
# smart_255_raw           331733
# Length: 197, dtype: int64

# %%
dataset.drop(dataset.columns[5:198],axis=1,inplace=True)

# %%
dataset.columns
# Out:
# Index(['date', 'serial_number', 'model', 'capacity_bytes', 'failure'], dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331733 entries, 0 to 331732
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            331733 non-null  object
#  1   serial_number   331733 non-null  object
#  2   model           331733 non-null  object
#  3   capacity_bytes  331733 non-null  float64
#  4   failure         331733 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 12.7+ MB

# %%
dataset.describe()
# Out:
#        capacity_bytes        failure
# count    3.317330e+05  331733.000000
# mean     1.533206e+13       0.000066
# std      4.256708e+12       0.008143
# min      2.400570e+11       0.000000
# 25%      1.200010e+13       0.000000
# 50%      1.600090e+13       0.000000
# 75%      1.600090e+13       0.000000
# max      2.400030e+13       1.000000

# %%
dataset
# Out:
#               date serial_number                model  capacity_bytes  failure
# 0       07-10-2025  2206E608DB42       CT250MX500SSD1    2.500590e+11        0
# 1       07-10-2025  2207E60CC65A       CT250MX500SSD1    2.500590e+11        0
# 2       07-10-2025  2340E87B92B5       CT250MX500SSD1    2.500590e+11        0
# 3       07-10-2025  2340E87B97E8       CT250MX500SSD1    2.500590e+11        0
# 4       07-10-2025  2407E896B6D5       CT250MX500SSD1    2.500590e+11        0
# ...            ...           ...                  ...             ...      ...
# 331728  07-10-2025      3ZHG6U1Z  WDC WUH722222ALE6L4    2.200100e+13        0
# 331729  07-10-2025      3ZHG6U9Z  WDC WUH722222ALE6L4    2.200100e+13        0
# 331730  07-10-2025      ZGG6LV5B  WDC WUH722222ALE6L4    2.200100e+13        0
# 331731  07-10-2025      ZGG7J1TA  WDC WUH722222ALE6L4    2.200100e+13        0
# 331732  07-10-2025      ZGG7RGNA  WDC WUH722222ALE6L4    2.200100e+13        0
#
# ...

# %%
dataset.cov(numeric_only=True)
# Out:
#                 capacity_bytes       failure
# capacity_bytes    1.811956e+25 -1.365347e+08
# failure          -1.365347e+08  6.631420e-05

# %%
dataset.describe()
# Out:
#        capacity_bytes        failure
# count    3.317330e+05  331733.000000
# mean     1.533206e+13       0.000066
# std      4.256708e+12       0.008143
# min      2.400570e+11       0.000000
# 25%      1.200010e+13       0.000000
# 50%      1.600090e+13       0.000000
# 75%      1.600090e+13       0.000000
# max      2.400030e+13       1.000000

# %%
dataset.corr(numeric_only=True)
# Out:
#                 capacity_bytes   failure
# capacity_bytes        1.000000 -0.003939
# failure              -0.003939  1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331733 entries, 0 to 331732
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            331733 non-null  object
#  1   serial_number   331733 non-null  object
#  2   model           331733 non-null  object
#  3   capacity_bytes  331733 non-null  float64
#  4   failure         331733 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 12.7+ MB

# %%
dataset.describe()
# Out:
#        capacity_bytes        failure
# count    3.317330e+05  331733.000000
# mean     1.533206e+13       0.000066
# std      4.256708e+12       0.008143
# min      2.400570e+11       0.000000
# 25%      1.200010e+13       0.000000
# 50%      1.600090e+13       0.000000
# 75%      1.600090e+13       0.000000
# max      2.400030e+13       1.000000

# %%
import seaborn as sns

# %%
sns.pairplot (dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    vif=pd.DataFrame()
    vif["variable"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return (vif)

# %%
dataset.columns
# Out:
# Index(['date', 'serial_number', 'model', 'capacity_bytes', 'failure'], dtype='object')

# %%
calc_vif(dataset[["capacity_bytes","failure"]])
# Out:
#          variable       VIF
# 0  capacity_bytes  1.000046
# 1         failure  0.999980

# %%
import scipy.stats as stats
stats.f_oneway(dataset['capacity_bytes'],dataset['failure'])
# Out:
# F_onewayResult(statistic=np.float64(4303699.698190223), pvalue=np.float64(0.0))
